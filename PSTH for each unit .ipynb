# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
trials_info = pd.read_csv('trials_info2', sep=',', index_col=0)  
trial_timings = pd.read_csv('trial_timings2', sep=',', index_col=0) 
spike_times = pd.read_pickle('./kluster2.kkp') 
trials_info = trial_timings.join(trials_info)

# %%
st=np.unique(trials_info['stim_name'].values).tolist()

# %%
#trials_info[trials_info['go_or_nogo']=='go']

# %%
trials_info
# Out:
#      choice_made  cpoke_start   cpoke_stop   stim_onset  is_munged  \
# 3      44.544420    43.540810    43.846445    43.815049      False
# 4      53.681896    52.812997    53.133077    53.101191      False
# 5      63.875632    62.973183    63.300413    63.225334      False
# 6      75.797537    74.834627    75.136773    75.084948      False
# 7      83.339737    82.383632    82.763516    82.710694      False
# 8      90.223821    89.348777    89.719856    89.678830      False
# 9      98.908156    97.914184    98.282107    98.230283      False
# 10    117.139421   115.694635   116.119368   116.039471      False
# 11    162.932274   161.527519   161.939294   161.832653      False
# 12    219.396586   218.113088   218.457258   218.369388      False
# 13    223.542252   222.111584   222.691954   222.442633      False
# 14    226.173699   225.293007   225.680531   225.551301      False
# 15    231.960489   231.098069   231.430945   231.394236      False
# 16    242.366015   241.519374   241.835473   241.780659      False
# 17    256.635986   255.248176   255.785530   255.536366      False
# 18    259.688847   258.793371   259.150831   259.074587      False
# 19    263.444661   262.042565   262.594036   262.344712      False
# 20    267.004807   265.620813   266.154180   265.904855      False
# 21    290.165756   289.182575   289.581561   289.471600      False
# 22    298.818367   297.395339   297.967739   297.718414      False
# 23    308.187223   307.140928   307.484766   307.437094      False
# 24    336.015248   335.282722   335.585367   335.537030      False
# 25    347.431361   346.408149   346.733384   346.702323      False
# 26    369.026431   368.113846   368.444068   368.408018      False
# 27    450.426199   449.072769   449.418768   449.326081      False
# 28    453.574566   452.659988   452.980904   452.948015      False
# 29    458.833805   457.798801   458.208915   458.137817      False
# 30    467.186093   465.776188   466.176340   466.086147      False
# 31    469.644961   468.747821   469.078204   469.030869      False
# 32    502.906294   501.928103   502.283569   502.244203      False
# ..           ...          ...          ...          ...        ...
# 909  7586.857427  7585.463468  7585.828567  7585.757641      False
# 910  7589.486879  7588.653527  7588.985735  7588.919795      False
# 911  7593.910773  7593.138881  7593.499662  7593.454978      False
# 912  7609.493481  7608.105169  7608.450172  7608.393364      False
# 913  7611.598207  7610.204248  7610.654560  7610.498255      False
# 914  7616.073925  7614.665183  7615.076626  7614.974139      False
# 915  7620.722222  7619.723267  7620.100992  7620.033220      False
# 916  7627.891355  7626.483272  7626.838744  7626.791403      False
# 917  7630.331774  7629.430152  7629.791265  7629.747249      False
# 918  7636.029034  7634.637064  7634.986386  7634.929082      False
# 919  7638.264982  7637.267684  7637.651388  7637.586772      False
# 920  7644.916020  7644.168545  7644.471522  7644.420860      False
# 921  7651.720043  7650.330071  7650.697329  7650.620256      False
# 922  7661.622763  7660.178974  7660.580287  7660.522976      False
# 923  7665.256661  7664.234613  7664.558020  7664.554699      False
# 924  7668.337922  7666.970872  7667.324179  7667.238136      False
# 925  7672.017661  7671.174841  7671.526486  7671.491936      False
# 926  7675.880948  7675.119354  7675.456382  7675.406550      False
# 927  7695.621282  7694.246258  7694.588936  7694.521330      False
# 928  7699.319128  7698.472155  7698.879612  7698.806192      False
# 929  7729.415651  7728.395432  7728.800730  7728.727475      False
# 930  7734.028907  7733.098716  7733.492386  7733.417803      False
# 931  7740.762833  7739.364055  7739.692613  7739.663046      False
# 932  7744.346070  7743.432483  7743.778315  7743.742602      False
# 933  7748.950514  7748.170482  7748.519799  7748.495551      False
# 934  7754.485655  7753.124750  7753.498654  7753.386036      False
# 935  7757.530539  7756.177275  7756.532243  7756.430587      False
# 936  7761.796964  7760.399018  7760.750992  7760.697012      False
# 937  7764.730058  7763.737409  7764.081581  7764.000688      False
# 938  7776.947630  7775.579417  7775.859473  7775.847679      False
#
#     correct_side  stim_number  nonrandom outcome go_or_nogo  block stim_name
# 3           left            3          1     hit         go      1  le_lc_go
# 4           left            3          1     hit         go      1  le_lc_go
# 5           left            3          1     hit         go      1  le_lc_go
# 6           left            3          1     hit         go      1  le_lc_go
# 7           left            3          1     hit         go      1  le_lc_go
# 8           left            3          1     hit         go      1  le_lc_go
# 9           left            3          0     hit         go      1  le_lc_go
# 10          left            4          0     hit       nogo      1  ri_lc_no
# 11          left            4          0     hit       nogo      1  ri_lc_no
# 12          left            4          0   error       nogo      1  ri_lc_no
# 13          left            4          0     hit       nogo      1  ri_lc_no
# 14          left            3          0     hit         go      1  le_lc_go
# 15          left            3          0     hit         go      1  le_lc_go
# 16          left            3          0     hit         go      1  le_lc_go
# 17          left            4          0     hit       nogo      1  ri_lc_no
# 18          left            4          0   error       nogo      1  ri_lc_no
# 19          left            4          0     hit       nogo      1  ri_lc_no
# 20          left            4          0     hit       nogo      1  ri_lc_no
# 21          left            9          0     hit         go      2  le_hi_lc
# 22          left           12          0     hit       nogo      2  ri_lo_lc
# 23          left            9          0     hit         go      2  le_hi_lc
# 24          left           11          0     hit         go      2  le_lo_lc
# 25          left            9          0     hit         go      2  le_hi_lc
# 26          left            9          0     hit         go      2  le_hi_lc
# 27          left           12          0     hit       nogo      2  ri_lo_lc
# 28          left           10          0   error       nogo      2  ri_hi_lc
# 29          left            9          0     hit         go      2  le_hi_lc
# 30          left           10          0     hit       nogo      2  ri_hi_lc
# 31          left            9          0     hit         go      2  le_hi_lc
# 32          left            9          0     hit         go      2  le_hi_lc
# ..           ...          ...        ...     ...        ...    ...       ...
# 909        right            6          0     hit       nogo      4  ri_hi_pc
# 910        right            6          0   error       nogo      4  ri_hi_pc
# 911        right            7          0     hit         go      4  le_lo_pc
# 912        right            5          0     hit       nogo      4  le_hi_pc
# 913        right            7          0   error         go      4  le_lo_pc
# 914        right            5          0     hit       nogo      4  le_hi_pc
# 915        right            7          0     hit         go      4  le_lo_pc
# 916        right            5          0     hit       nogo      4  le_hi_pc
# 917        right            6          0   error       nogo      4  ri_hi_pc
# 918        right            5          0     hit       nogo      4  le_hi_pc
# 919        right            7          0     hit         go      4  le_lo_pc
# 920        right            8          0     hit         go      4  ri_lo_pc
# 921        right            6          0     hit       nogo      4  ri_hi_pc
# 922        right            5          0     hit       nogo      4  le_hi_pc
# 923        right            6          0   error       nogo      4  ri_hi_pc
# 924        right            6          0     hit       nogo      4  ri_hi_pc
# 925        right            7          0     hit         go      4  le_lo_pc
# 926        right            7          0     hit         go      4  le_lo_pc
# 927        right            5          0     hit       nogo      4  le_hi_pc
# 928        right            8          0     hit         go      4  ri_lo_pc
# 929        right            6          0   error       nogo      4  ri_hi_pc
# 930        right            8          0     hit         go      4  ri_lo_pc
# 931        right            5          0     hit       nogo      4  le_hi_pc
# 932        right            7          0     hit         go      4  le_lo_pc
# 933        right            6          0   error       nogo      4  ri_hi_pc
# 934        right            7          0   error         go      4  le_lo_pc
# 935        right            7          0   error         go      4  le_lo_pc
# 936        right            7          0   error         go      4  le_lo_pc
# 937        right            6          0   error       nogo      4  ri_hi_pc
# 938        right            7          0   error         go      4  le_lo_pc
#
# [936 rows x 12 columns]

# %%
#trials_info

# %%
def passing(N):
    l=[]
    for item in N:
        x=item*1000/1000
        y="%.3f" % x
        z=float(y)
        l.append(z)
        
        
    return l

# %%
gr=spike_times[spike_times['group']>4]
gr=gr.sort_values(by=['time']).reset_index()
u=np.unique(gr['unit'].values)

# %%
time_axes=np.zeros(8000000)

# %%
def unit(gr,units, time_axes):
    
    
    time=time_axes.astype(int).reshape(-1,1)
    
                      
    for number in units:
        
        val=np.array(passing(gr[gr['unit']==number]['time'].values))*1000
        
        h=val.astype(int).tolist()
        
        time_ax=np.zeros(8000000).astype(int)
        
        time_ax[h]=1
        
        time=np.append(time, time_ax.reshape(-1,1), axis=1)
        
    return time

# %%
units_col=unit(gr, u, time_axes)

# %%
np.unique(units_col, return_counts=True)
# Out:
# (array([0, 1]), array([415135408,    864592], dtype=int64))

# %%
df_units=pd.DataFrame(units_col)
df_units=df_units.drop(df_units.columns[[0]], axis = 1)

# %%
df_units.columns=u

# %%
def all_stimulus(st, trials_info):
    df=pd.DataFrame(np.zeros(8000000))
    
    for value in st: 
        ar=np.array(passing(np.sort(trials_info[trials_info['stim_name']==value]['stim_onset'].values)))*1000
        ev_ar=evoked(ar)
        df[value]=ev_ar
    return df

# %%
stim_t=all_stimulus(st, trials_info)

# %%
def modify_array(h):
    ar=h.astype(int)
    val=np.unique(ar)
   
    
    for v in val:
       
        ind=np.where(ar==v)[0].astype(int).tolist()
        ins=np.arange(int(v), int(v)+251, 1).astype(int)
        ar=np.insert(ar.astype(int), ind[0], ins)
        
    return ar

# %%
def evoked(array):
    

    t=np.zeros(8000000).astype(int)
    indices=modify_array(array)
    ind=indices.astype(int).tolist()
    t[ind]=1
    
    return t

# %%
def pres(start, d):
    ar=start.astype(int)
    val=np.unique(ar)
    counter=0
    for v in val:
        
        ind=np.where(ar==v)[0].astype(int).tolist()
        ins=np.arange(int(v), int(v)+int(d[counter]), 1).astype(int)
        ar=np.insert(ar.astype(int), ind[0], ins)
        counter=counter+1
    return ar

# %%
def pres_evoked(array, d):
    
    

    t=np.zeros(8000000).astype(int)
    indices=pres(array, d)
    ind=indices.astype(int).tolist()
    t[ind]=1
    
    return t

# %%
def all_prestimulus(st, trials_info):
    df=pd.DataFrame(np.zeros(8000000))
    for value in st:
        pres=trials_info[trials_info['stim_name']==value]['cpoke_start'].values
        d=(np.array(passing(trials_info[trials_info['stim_name']==value]['stim_onset'].values))-np.array(passing(trials_info[trials_info['stim_name']==value]['cpoke_start'].values)))*1000
        d=d.astype(int)
        pres=np.array(passing(pres))*1000
        prestimulus=pres_evoked(pres, d)
        df[value+"pres"]=prestimulus
    return df

# %%
pres_t=all_prestimulus(st, trials_info)

# %%
df=pd.concat([df_units, pres_t.drop(pres_t.columns[[0]], axis = 1), stim_t.drop(stim_t.columns[[0]], axis = 1)], axis=1)

# %%
df.columns
# Out:
# Index([           501,            502,            503,            504,
#                   505,            506,            507,            508,
#                   509,            510,            511,            512,
#                   601,            602,            604,            605,
#                   606,            607,            608,            609,
#                   611,            612,            701,            702,
#                   706,            707,            708,            710,
#                   711,            712,            713,            715,
#                   801,            802,            803,            804,
#                   805,            806,            807,            808,
#                   809,            810,            811,            812,
#                   813,            814,            815,            816,
#                   817,            818,            819, 'hi_pc_nopres',
#        'le_hi_lcpres', 'le_hi_pcpres', 'le_lc_gopres', 'le_lo_lcpres',
#        'le_lo_pcpres', 'lo_pc_gopres', 'ri_hi_lcpres', 'ri_hi_pcpres',
#        'ri_lc_nopres', 'ri_lo_lcpres', 'ri_lo_pcpres',     'hi_pc_no',
#            'le_hi_lc',     'le_hi_pc',     'le_lc_go',     'le_lo_lc',
#            'le_lo_pc',     'lo_pc_go',     'ri_hi_lc',     'ri_hi_pc',
#            'ri_lc_no',     'ri_lo_lc',     'ri_lo_pc'],
#       dtype='object')

# %%
df['indexes']=df.index

# %%
def to_f(D):

# %%
stim=df[df['le_hi_lc']==1]

# %%
len(stim)/251
# Out:
# 87.0

# %%
df.iloc[:, 74].head().name
# Out:
# 'ri_lo_pc'

# %%
for i in range (0, 50):
    
    
    stim=df[df['le_hi_lc']==1]
    single_stim=stim.iloc[:, i].values.reshape(87,251)
    name=stim.iloc[:,i].head().name
    ind=stim.iloc[:,i].index.values.reshape(87,251)
    idd=ind[:,0]
    mean_count=per_trial(df, idd, single_stim).tolist()
    m_r=[l/86 for l in mean_count]
    pd.DataFrame(m_r).to_csv(str(name)+'le_hi_lc.csv')

# %%
   
  
  
    
for i in range (3, 50):
    for n in range(51, 75):
        if not str(df.iloc[:,n].head().name).endswith('pres'):
            number=df.iloc[:,n].head().name
            
            stim=df[df[str(df.iloc[:,n].head().name)]==1]
            ln=len(stim)/251
            single_stim=stim.iloc[:, i].values.reshape(int(ln), 251)
            name=stim.iloc[:,i].head().name
            ind=stim.iloc[:,i].index.values.reshape(int(ln), 251)
            idd=ind[:,0]
            mean_count=per_trial(df, idd, single_stim, number, ln).tolist()
            m_r=[l/(int(ln)-1) for l in mean_count]
            pd.DataFrame(m_r).to_csv(str(name)+str(number)+'.csv')

# %%
 def per_trial(df, idd, single_stim, number, ln):
        b=np.zeros(13)
      
        
        for t in range(1, int(ln)):
            
            
            
            
            temp_t=single_stim[t].tolist()
            pres_t=df[(df['indexes'] < int(idd[t])) & (df[str(number)+'pres']==1)&(df['indexes'] > int(idd[t-1]))]
            pres=pres_t.iloc[:, i].values.tolist()
            all=pres+temp_t
            all_equal=all+ np.zeros(650-len(all)).tolist()
                                 
            a=np.array(all_equal).reshape(13, 50).tolist()
            a=[sub.count(1)*20 for sub in a ]
            b=b+np.array(a)    
            
        return b
